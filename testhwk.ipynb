# %%
ls
# Out:
#  Volume in drive C is Windows7_OS
#  Volume Serial Number is 560D-0DD8
#
#  Directory of C:\Users\abi\desktop
#
# 03/18/2014  08:13 PM    <DIR>          .
# 03/18/2014  08:13 PM    <DIR>          ..
# 03/13/2014  09:02 AM    <DIR>          Software
# 03/10/2014  12:14 PM           536,064 sqlite3.exe
#                1 File(s)        536,064 bytes
#                3 Dir(s)  443,992,952,832 bytes free

# %%
import pandas as pd
data = pd.read_csv('titanic-train.csv')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-2082d2641b86> in <module>()
#       1 import pandas as pd
# ----> 2 data = pd.read_csv('titanic-train.csv')
#
# ...
